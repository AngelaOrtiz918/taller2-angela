# %% [markdown]
# # Analítica computacional para la toma de decisiones
#
# Departamento de Ingeniería Industrial
#
# Universidad de los Andes

# %% [markdown]
# ## Exploración de datos en python

# %% [markdown]
# ### Importar Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importar Dataset

# %%
df = pd.read_csv('.\\BankChurn.csv')

# %%
df.shape
#df
# Out:
# (10127, 20)

# %%
df.head()
# Out:
#       Attrition_Flag  Customer_Age Gender  Dependent_count Education_Level  \
# 0  Existing Customer            45      M                3     High School
# 1  Existing Customer            49      F                5        Graduate
# 2  Existing Customer            51      M                3        Graduate
# 3  Existing Customer            40      F                4     High School
# 4  Existing Customer            40      M                3      Uneducated
#
#   Marital_Status Income_Category Card_Category  Months_on_book  \
# 0        Married     $60K - $80K          Blue              39
# 1         Single  Less than $40K          Blue              44
# 2        Married    $80K - $120K          Blue              36
# 3        Unknown  Less than $40K          Blue              34
# 4        Married     $60K - $80K          Blue              21
#
#    Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# ...

# %%
df["Attrition_Flag"].unique()
# Out:
# array(['Existing Customer', 'Attrited Customer'], dtype=object)

# %%
df.groupby(["Attrition_Flag"]).count()
# Out:
#                    Customer_Age  Gender  Dependent_count  Education_Level  \
# Attrition_Flag
# Attrited Customer          1627    1627             1627             1627
# Existing Customer          8500    8500             8500             8500
#
#                    Marital_Status  Income_Category  Card_Category  \
# Attrition_Flag
# Attrited Customer            1627             1627           1627
# Existing Customer            8500             8500           8500
#
#                    Months_on_book  Total_Relationship_Count  \
# Attrition_Flag
# Attrited Customer            1627                      1627
# Existing Customer            8500                      8500
#
#                    Months_Inactive_12_mon  Contacts_Count_12_mon  \
# Attrition_Flag
# Attrited Customer                    1627                   1627
# Existing Customer                    8500                   8500
#
#                    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# Attrition_Flag
# ...

# %%
df["Attrition_Flag"].value_counts()
# Out:
# Attrition_Flag
# Existing Customer    8500
# Attrited Customer    1627
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        Customer_Age  Dependent_count  Months_on_book  \
# count  10127.000000     10127.000000    10127.000000
# mean      46.325960         2.346203       35.928409
# std        8.016814         1.298908        7.986416
# min       26.000000         0.000000       13.000000
# 25%       41.000000         1.000000       31.000000
# 50%       46.000000         2.000000       36.000000
# 75%       52.000000         3.000000       40.000000
# max       73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# 50%                    4.000000                2.000000
# 75%                    5.000000                3.000000
# ...

# %%
# número de clientes perdido y no perdidosn
counts = df.Attrition_Flag.value_counts()
print(counts.iloc[1])
perc_churn = (counts.iloc[1] / (counts.iloc[0] + counts.iloc[1])) * 100
print(f'Churn Rate = {perc_churn:.1f}%')
# Out:
# 1627
# Churn Rate = 16.1%

# %%
# número de duplicados
duplicates = len(df[df.duplicated()])
print(f'Number of Duplicate Entries: {duplicates}')
# Out:
# Number of Duplicate Entries: 0

# %%
# número de valores perdidos
missing_values = df.isnull().sum().sum()
print(f'Number of Missing Values: {missing_values}')
# Out:
# Number of Missing Values: 0

# %%
# Tipos de datos en el dataset
types = df.dtypes.value_counts()

print('Number of Features: %d'%(df.shape[1]))
print('Number of Customers: %d'%(df.shape[0]))
print('Data Types and Frequency in Dataset:')
print(types)
# Out:
# Number of Features: 20
# Number of Customers: 10127
# Data Types and Frequency in Dataset:
# int64      9
# object     6
# float64    5
# Name: count, dtype: int64

# %% [markdown]
# ## Pre-Processing

# %%
# Conversión de características
df['Gender'] = df['Gender'].map({'M': 1, 'F': 0})
df['Attrition_Flag'] = df['Attrition_Flag'].map({'Attrited Customer': 1, 'Existing Customer': 0})

# %%
catcols = df.select_dtypes(exclude = ['int64','float64']).columns
intcols = df.select_dtypes(include = ['int64']).columns
floatcols = df.select_dtypes(include = ['float64']).columns

# codificación 
df = pd.get_dummies(df, columns = catcols)
   
print('New Number of Features: %d'%(df.shape[1]))
# Out:
# New Number of Features: 37

# %%
#Boxplot

# Crear el boxplot
df.boxplot("Credit_Limit","Attrition_Flag", grid=True,figsize=(6,5))

# Mostrar el gráfico
#plt.title('Boxplot de Categorías')
plt.ylabel('Límite de crédito')
plt.show()

# %%
#Scatter Plot

plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Customer_Age', y='Credit_Limit', hue='Attrition_Flag', palette='tab10', s=100)
plt.title('Relación entre la edad del cliente y el límite de crédito', fontsize=14)
plt.xlabel('Customer_Age', fontsize=12)
plt.ylabel('Credit_Limit', fontsize=12)
plt.legend(title='Attrition_Flag', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Histograma

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Customer_Age'], kde=True, color='skyblue', bins=10)
plt.title('Distribución de la edad de los clientes', fontsize=14)
plt.xlabel('Edad de los clientes', fontsize=12)
plt.ylabel('Frecuencia', fontsize=12)
plt.show()

# %%
# Crear el gráfico de barras con estilo mejorado
plt.figure(figsize=(12, 8))
sns.set(style="whitegrid")
bar_plot = sns.barplot(x='Customer_Age', y='Total_Trans_Amt', data=df, palette='viridis')

# Mejorar las etiquetas y título
bar_plot.set_xlabel('Edad del Cliente', fontsize=14)
bar_plot.set_ylabel('Monto Total de Transacciones', fontsize=14)
bar_plot.set_title('Monto Total de Transacciones por Edad del Cliente', fontsize=16)
bar_plot.bar_label(bar_plot.containers[0], fmt='%.0f')

# Rotar las etiquetas del eje X si es necesario
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\ma.soriano\AppData\Local\Temp\ipykernel_12580\12724783.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bar_plot = sns.barplot(x='Customer_Age', y='Total_Trans_Amt', data=df, palette='viridis')
